# %% [markdown]
# <a href="https://colab.research.google.com/github/alexsandroprado/alexsandroprado.github.io/blob/master/src/yahoo_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install yfinance

# %%
import yfinance as yf

df = yf.download("PETR4.SA", start="2025-01-01", end="2025-02-16")
df.columns
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'PETR4.SA'),
#             (  'High', 'PETR4.SA'),
#             (   'Low', 'PETR4.SA'),
#             (  'Open', 'PETR4.SA'),
#             ('Volume', 'PETR4.SA')],
#            names=['Price', 'Ticker'])

# %%
petr4 = yf.Ticker("PETR4.SA")

info = petr4.fast_info.toJSON()
print(info)
# Out:
# {
#     "currency": "BRL",
#     "dayHigh": 31.530000686645508,
#     "dayLow": 31.360000610351562,
#     "exchange": "SAO",
#     "fiftyDayAverage": 33.085799865722656,
#     "lastPrice": 31.389999389648438,
#     "lastVolume": 839100,
#     "marketCap": 420051541774.21875,
#     "open": 31.459999084472656,
#     "previousClose": 31.299999237060547,
#     "quoteType": "EQUITY",
#     "regularMarketPreviousClose": 31.399999618530273,
#     "shares": 13381699584,
#     "tenDayAverageVolume": 37864920,
#     "threeMonthAverageVolume": 44235880,
#     "timezone": "America/Sao_Paulo",
#     "twoHundredDayAverage": 36.21029993057251,
#     "yearChange": -0.15158062570726769,
#     "yearHigh": 40.7599983215332,
#     "yearLow": 29.65999984741211
# }

# %%
df = petr4.history(start="2025-01-01", end="2025-02-16")
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2025-02-10 00:00:00-03:00  35.936780  36.151559  35.848915  35.956306
# 2025-02-11 00:00:00-03:00  36.132033  36.210137  35.809863  35.956306
# 2025-02-12 00:00:00-03:00  35.780575  35.878201  35.253384  35.419350
# 2025-02-13 00:00:00-03:00  35.341248  35.468166  35.165518  35.458401
# 2025-02-14 00:00:00-03:00  35.575553  36.688512  35.536504  36.551830
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-02-10 00:00:00-03:00  17483300        0.0           0.0
# 2025-02-11 00:00:00-03:00  16624300        0.0           0.0
# 2025-02-12 00:00:00-03:00  37364500        0.0           0.0
# 2025-02-13 00:00:00-03:00  15351300        0.0           0.0
# 2025-02-14 00:00:00-03:00  40322000        0.0           0.0
